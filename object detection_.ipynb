# %%
pip install yolov5
# Out:
# Collecting yolov5
#   Downloading yolov5-7.0.12-py37.py38.py39.py310-none-any.whl (953 kB)
#      ------------------------------------ 953.3/953.3 kB 321.1 kB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from yolov5) (4.7.0.68)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from yolov5) (0.12.0)
# Collecting sahi>=0.11.10
#   Downloading sahi-0.11.14-py3-none-any.whl (104 kB)
#      ------------------------------------ 104.0/104.0 kB 176.6 kB/s eta 0:00:00
# Collecting fire
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      -------------------------------------- 88.3/88.3 kB 113.6 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting ultralytics>=8.0.100
#   Downloading ultralytics-8.0.109-py3-none-any.whl (591 kB)
#      ------------------------------------ 591.4/591.4 kB 108.1 kB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1.4 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from yolov5) (1.4.4)
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from yolov5) (1.23.3)
# Collecting tqdm>=4.64.0
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      --------------------------------------- 77.1/77.1 kB 95.1 kB/s eta 0:00:00
# Requirement already satisfied: psutil in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from yolov5) (5.9.2)
# Requirement already satisfied: tensorboard>=2.4.1 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from yolov5) (2.11.2)
# Collecting gitpython>=3.1.30
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ------------------------------------- 184.3/184.3 kB 55.7 kB/s eta 0:00:00
# Collecting setuptools>=65.5.1
#   Downloading setuptools-67.8.0-py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 76.6 kB/s eta 0:00:00
# Collecting boto3>=1.19.1
#   Downloading boto3-1.26.141-py3-none-any.whl (135 kB)
#      ------------------------------------- 135.6/135.6 kB 43.6 kB/s eta 0:00:00
# Collecting torch>=1.7.0
#   Downloading torch-2.0.1-cp310-cp310-win_amd64.whl (172.3 MB)
#      --                                     11.5/172.3 MB 29.4 kB/s eta 1:31:07
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\urllib3\response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\urllib3\response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 90, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\http\client.py", line 465, in read
#     s = self.fp.read(amt)
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\ssl.py", line 1274, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\ssl.py", line 1130, in read
#     return self._sslobj.read(len, buffer)
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\cli\base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\cli\req_command.py", line 247, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\commands\install.py", line 415, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 92, in resolve
#     result = self._result = resolver.resolve(
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 481, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 373, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 213, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 204, in _get_updated_criteria
#     self._add_to_criteria(criteria, requirement, parent=candidate)
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 172, in _add_to_criteria
#     if not criterion.candidates:
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\resolvelib\structs.py", line 151, in __bool__
#     return bool(self._sequence)
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 155, in __bool__
#     return any(self)
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 143, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 47, in _iter_built
#     candidate = func()
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 206, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 297, in __init__
#     super().__init__(
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 162, in __init__
#     self.dist = self._prepare()
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 231, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 308, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\operations\prepare.py", line 491, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\operations\prepare.py", line 536, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\operations\prepare.py", line 166, in unpack_url
#     file = get_http_url(
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\operations\prepare.py", line 107, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\network\download.py", line 147, in __call__
#     for chunk in chunks:
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\cli\progress_bars.py", line 53, in _rich_progress_bar
#     for chunk in iterable:
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\network\utils.py", line 63, in response_chunks
#     for chunk in response.raw.stream(
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\urllib3\response.py", line 622, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\urllib3\response.py", line 560, in read
#     with self._error_catcher():
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\contextlib.py", line 153, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\urllib3\response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.
#
# [notice] A new release of pip is available: 23.0 -> 23.1.2
# [notice] To update, run: C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip

# %%
pip install ultralytics
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script isympy.exe is installed in 'C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts convert-caffe2-to-onnx.exe, convert-onnx-to-caffe2.exe and torchrun.exe are installed in 'C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts ultralytics.exe and yolo.exe are installed in 'C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 23.0 -> 23.1.2
# [notice] To update, run: C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip
# Collecting ultralytics
#   Using cached ultralytics-8.0.109-py3-none-any.whl (591 kB)
# Collecting PyYAML>=5.3.1
#   Downloading PyYAML-6.0-cp310-cp310-win_amd64.whl (151 kB)
#      ------------------------------------- 151.7/151.7 kB 48.7 kB/s eta 0:00:00
# Requirement already satisfied: requests>=2.23.0 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.28.2)
# Collecting tqdm>=4.64.0
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Requirement already satisfied: psutil in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (5.9.2)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (1.4.4)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (0.12.0)
# Collecting sentry-sdk
#   Downloading sentry_sdk-1.24.0-py2.py3-none-any.whl (206 kB)
#      ------------------------------------- 206.5/206.5 kB 60.4 kB/s eta 0:00:00
# Collecting torch>=1.7.0
#   Downloading torch-2.0.1-cp310-cp310-win_amd64.whl (172.3 MB)
#      -------------------------------------- 172.3/172.3 MB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (3.6.0)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (4.7.0.68)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (1.9.1)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (9.2.0)
# Collecting torchvision>=0.8.1
#   Using cached torchvision-0.15.2-cp310-cp310-win_amd64.whl (1.2 MB)
# Requirement already satisfied: numpy>=1.19 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (1.23.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (4.37.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (1.0.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.1.4->ultralytics) (2022.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: jinja2 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.7.0->ultralytics) (3.1.2)
# Requirement already satisfied: typing-extensions in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.7.0->ultralytics) (4.4.0)
# Collecting filelock
#   Downloading filelock-3.12.0-py3-none-any.whl (10 kB)
# Collecting sympy
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ---------------------------------------- 5.7/5.7 MB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: networkx in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.7.0->ultralytics) (3.0)
# Requirement already satisfied: colorama in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.5)
# Requirement already satisfied: six>=1.5 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch>=1.7.0->ultralytics) (2.1.1)
# Collecting mpmath>=0.19
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      -------------------------------------- 536.2/536.2 kB 6.7 MB/s eta 0:00:00
# Installing collected packages: mpmath, tqdm, sympy, sentry-sdk, PyYAML, filelock, torch, torchvision, ultralytics
# Successfully installed PyYAML-6.0 filelock-3.12.0 mpmath-1.3.0 sentry-sdk-1.24.0 sympy-1.12 torch-2.0.1 torchvision-0.15.2 tqdm-4.65.0 ultralytics-8.0.109

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (4.7.0.68)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\chirag hk\appdata\local\programs\python\python310\lib\site-packages (from opencv-python) (1.23.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0 -> 23.1.2
# [notice] To update, run: C:\Users\Chirag HK\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip

# %%
import torch
import cv2
import numpy as np

def POINTS(event, x, y, flags, param):
    if event == cv2.EVENT_MOUSEMOVE:
        colorsBGR = [x, y]
        print(colorsBGR)

cv2.namedWindow('ROI')
cv2.setMouseCallback('ROI', POINTS)

image_path = 'D:/sowmya/NHCE/NHCE/Academic Even 2023/Deep learning Lab/image 2.jpg'  # Path to your image file

model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

frame = cv2.imread(image_path)
frame = cv2.resize(frame, (1020, 500))
results = model(frame)

for index, row in results.pandas().xyxy[0].iterrows():
    x1 = int(row['xmin'])
    y1 = int(row['ymin'])
    x2 = int(row['xmax'])
    y2 = int(row['ymax'])
    d = row['name']
    print(d)
    cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 255, 255), 2)
    cv2.putText(frame, d, (x1, y1 + 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255))
    
cv2.imshow("ROI", frame)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Using cache found in C:\Users\Chirag HK/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-5-26 Python-3.10.7 torch-2.0.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# car
# [989, 8]
# [944, 48]
# [910, 78]
# [876, 108]
# [839, 148]
# [802, 183]
# [763, 218]
# [726, 253]
# [696, 276]
# [655, 307]
# [627, 328]
# [605, 344]
# [585, 359]
# [566, 374]
# [556, 382]
# [545, 396]
# [537, 406]
# [531, 414]
# [526, 422]
# [524, 424]
# [523, 425]
# [522, 425]
# [521, 426]
# [521, 426]
# [521, 426]
# [542, 419]
# [564, 411]
# [603, 398]
# [630, 390]
# [651, 385]
# [679, 378]
# [700, 373]
# [734, 368]
# [761, 363]
# [789, 360]
# [817, 356]
# [842, 356]
# [883, 356]
# [907, 356]
# [929, 356]
# [972, 356]
# [1008, 355]
# [1005, 136]
# [989, 114]
# [985, 104]
# [981, 94]
# [979, 88]
# [977, 84]
# [976, 80]
# [975, 74]
# [975, 69]
# [977, 62]
# [977, 58]
# [979, 54]
# [979, 50]
# [979, 43]
# [980, 34]
# [981, 29]
# [982, 24]
# [983, 20]
# [983, 17]
# [984, 15]
# [984, 13]
# [985, 12]
# [985, 10]
# [985, 10]
# [985, 9]
# [985, 8]
# [985, 8]
# [986, 7]
# [987, 6]
# [987, 6]
# [987, 5]
# [987, 4]
# [988, 4]
# [988, 3]
# [989, 3]
# [989, 2]
# [989, 2]
# [989, 1]
# [989, 0]
